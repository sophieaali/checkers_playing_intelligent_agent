# %%
from typing import List
from enum import Enum, auto
import numpy as np
import random
from copy import deepcopy
# from anytree import Node, RenderTree
# from anytree.exporter import UniqueDotExporter

import matplotlib.pyplot as plt


from Location import Location
from CheckerBoard import CheckerBoard
from NaiveAgent import NaiveAgent
from Move import Move
from Game import Game
from IntelligentAgent import IntelligentAgent
# Out:
# c:\Users\sophi\miniconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\sophi\miniconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
# c:\Users\sophi\miniconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
# Testing the Naive agents playing against each other

Game().run()
# Out:
# Initialize Board:
# 0 |    |B1  |    |B2  |    |B3  |    |B4  |
# 1 |B5  |    |B6  |    |B7  |    |B8  |    |
# 2 |    |B9  |    |B10 |    |B11 |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |W1  |    |W2  |    |W3  |    |W4  |    |
# 6 |    |W5  |    |W6  |    |W7  |    |W8  |
# 7 |W9  |    |W10 |    |W11 |    |W12 |    |
#     0    1    2    3    4    5    6    7
#
#
# Black's turn (turn 1):
# black_piece_9 moved from Location(x=2, y=1) to Location(x=3, y=2)
#
# 0 |    |B1  |    |B2  |    |B3  |    |B4  |
# 1 |B5  |    |B6  |    |B7  |    |B8  |    |
# 2 |    |    |    |B10 |    |B11 |    |B12 |
# 3 |    |    |B9  |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |W1  |    |W2  |    |W3  |    |W4  |    |
# 6 |    |W5  |    |W6  |    |W7  |    |W8  |
# 7 |W9  |    |W10 |    |W11 |    |W12 |    |
#     0    1    2    3    4    5    6    7
# ...

# %%
# play the checkers game 1000 times with 2 naive agents to see the win rate

Game().run_naive_multiple_games(1000)
# Out:
# Playing Game 1:
# Black wins!
#
#
# Playing Game 2:
# Black wins!
#
#
# Playing Game 3:
# White wins!
#
#
# Playing Game 4:
# Black wins!
#
#
# Playing Game 5:
# White wins!
#
#
# Playing Game 6:
# White wins!
#
#
# Playing Game 7:
# White wins!
#
#
# Playing Game 8:
# White wins!
#
#
# Playing Game 9:
# White wins!
#
#
# Playing Game 10:
# White wins!
#
#
# Playing Game 11:
# Black wins!
#
#
# Playing Game 12:
# Black wins!
#
#
# Playing Game 13:
# White wins!
#
#
# Playing Game 14:
# White wins!
#
#
# Playing Game 15:
# Black wins!
#
#
# Playing Game 16:
# Black wins!
#
#
# Playing Game 17:
# Black wins!
#
#
# Playing Game 18:
# White wins!
#
#
# Playing Game 19:
# Black wins!
#
#
# Playing Game 20:
# Black wins!
#
#
# Playing Game 21:
# Black wins!
#
#
# Playing Game 22:
# No possible moves for black, white wins
# White wins!
# No possible moves for black, white wins
#
#
# Playing Game 23:
# Black wins!
#
#
# Playing Game 24:
# White wins!
#
#
# Playing Game 25:
# Black wins!
#
#
# ...
