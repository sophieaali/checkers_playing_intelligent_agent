# %%
from typing import List
from enum import Enum, auto
import numpy as np
import random
import re
from copy import deepcopy
import matplotlib.pyplot as plt


from Location import Location
from CheckerBoard import CheckerBoard
from NaiveAgent import NaiveAgent
from Move import Move
from Game import Game
from IntelligentAgent import IntelligentAgent

# %% [markdown]
# # Summary from Testing my Intelligent Agent playing against a Naive Agent
# (see code and results below)
#
# ##### With a minimax algorithm depth of 2:
# - Black wins: 10
# - White wins: 0
# - Average game duration: 1.85 seconds
# - Average number of turns to win: 53.20
#
# ##### With a minimax algorithm depth of 3:
# - Black wins: 10
# - White wins: 0
# - Average game duration: 10.78 seconds
# - Average number of turns to win: 53.40
#
# ##### With a minimax algorithm depth of 4:
# - Black wins: 10
# - White wins: 0
# - Average game duration: 38.24 seconds
# - Average number of turns to win: 46.30
#
# ##### With a minimax algorithm depth of 5:
# - Black wins: 10
# - White wins: 0
# - Average game duration: 183.17 seconds
# - Average number of turns to win: 43.10

# %%
# Testing the Checkers game with a NaiveAgent playing against an IntelligentAgent
###  the default parameters are:
#       Black is the IntelligentAgent and White is the NaiveAgent
#       The minimax algorithm has a depth of 3

Game().run_with_ia()
# Out:
# Black is the Intelligent Agent, White is the Naive Agent
# Initialize Board:
# 0 |    |B1  |    |B2  |    |B3  |    |B4  |
# 1 |B5  |    |B6  |    |B7  |    |B8  |    |
# 2 |    |B9  |    |B10 |    |B11 |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |W1  |    |W2  |    |W3  |    |W4  |    |
# 6 |    |W5  |    |W6  |    |W7  |    |W8  |
# 7 |W9  |    |W10 |    |W11 |    |W12 |    |
#     0    1    2    3    4    5    6    7
#
#
# Black's turn (turn 1):
#
# 0 |    |B1  |    |B2  |    |B3  |    |B4  |
# 1 |B5  |    |B6  |    |B7  |    |B8  |    |
# 2 |    |    |    |B10 |    |B11 |    |B12 |
# 3 |B9  |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |W1  |    |W2  |    |W3  |    |W4  |    |
# 6 |    |W5  |    |W6  |    |W7  |    |W8  |
# 7 |W9  |    |W10 |    |W11 |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=0, y=1), 'black_piece_2': Location(x=0, y=3), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=1, y=0), 'black_piece_6': Location(x=1, y=2), 'black_piece_7': Location(x=1, y=4), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_10': Location(x=2, y=3), 'black_piece_11': Location(x=2, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_1': Location(x=5, y=0), 'white_piece_2': Location(x=5, y=2), 'white_piece_3': Location(x=5, y=4), 'white_piece_4': Location(x=5, y=6), 'white_piece_5': Location(x=6, y=1), 'white_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=6, y=5), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=7, y=4), 'white_piece_12': Location(x=7, y=6)}
#
#
# White's turn (turn 2):
#
# 0 |    |B1  |    |B2  |    |B3  |    |B4  |
# 1 |B5  |    |B6  |    |B7  |    |B8  |    |
# 2 |    |    |    |B10 |    |B11 |    |B12 |
# 3 |B9  |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |W3  |    |    |
# 5 |W1  |    |W2  |    |    |    |W4  |    |
# 6 |    |W5  |    |W6  |    |W7  |    |W8  |
# 7 |W9  |    |W10 |    |W11 |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=0, y=1), 'black_piece_2': Location(x=0, y=3), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=1, y=0), 'black_piece_6': Location(x=1, y=2), 'black_piece_7': Location(x=1, y=4), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_10': Location(x=2, y=3), 'black_piece_11': Location(x=2, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_1': Location(x=5, y=0), 'white_piece_2': Location(x=5, y=2), 'white_piece_3': Location(x=4, y=5), 'white_piece_4': Location(x=5, y=6), 'white_piece_5': Location(x=6, y=1), 'white_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=6, y=5), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=7, y=4), 'white_piece_12': Location(x=7, y=6)}
#
#
# Black's turn (turn 3):
#
# 0 |    |B1  |    |B2  |    |B3  |    |B4  |
# 1 |    |    |B6  |    |B7  |    |B8  |    |
# 2 |    |B5  |    |B10 |    |B11 |    |B12 |
# 3 |B9  |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |W3  |    |    |
# 5 |W1  |    |W2  |    |    |    |W4  |    |
# 6 |    |W5  |    |W6  |    |W7  |    |W8  |
# 7 |W9  |    |W10 |    |W11 |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=0, y=1), 'black_piece_2': Location(x=0, y=3), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=1, y=2), 'black_piece_7': Location(x=1, y=4), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_10': Location(x=2, y=3), 'black_piece_11': Location(x=2, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_1': Location(x=5, y=0), 'white_piece_2': Location(x=5, y=2), 'white_piece_3': Location(x=4, y=5), 'white_piece_4': Location(x=5, y=6), 'white_piece_5': Location(x=6, y=1), 'white_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=6, y=5), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=7, y=4), 'white_piece_12': Location(x=7, y=6)}
#
#
# White's turn (turn 4):
#
# 0 |    |B1  |    |B2  |    |B3  |    |B4  |
# 1 |    |    |B6  |    |B7  |    |B8  |    |
# 2 |    |B5  |    |B10 |    |B11 |    |B12 |
# 3 |B9  |    |    |    |W3  |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |W1  |    |W2  |    |    |    |W4  |    |
# 6 |    |W5  |    |W6  |    |W7  |    |W8  |
# 7 |W9  |    |W10 |    |W11 |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=0, y=1), 'black_piece_2': Location(x=0, y=3), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=1, y=2), 'black_piece_7': Location(x=1, y=4), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_10': Location(x=2, y=3), 'black_piece_11': Location(x=2, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_1': Location(x=5, y=0), 'white_piece_2': Location(x=5, y=2), 'white_piece_3': Location(x=3, y=4), 'white_piece_4': Location(x=5, y=6), 'white_piece_5': Location(x=6, y=1), 'white_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=6, y=5), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=7, y=4), 'white_piece_12': Location(x=7, y=6)}
#
#
# Black's turn (turn 5):
#
# 0 |    |B1  |    |B2  |    |B3  |    |B4  |
# 1 |    |    |B6  |    |B7  |    |B8  |    |
# 2 |    |B5  |    |    |    |B11 |    |B12 |
# 3 |B9  |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |B10 |    |    |
# 5 |W1  |    |W2  |    |    |    |W4  |    |
# 6 |    |W5  |    |W6  |    |W7  |    |W8  |
# 7 |W9  |    |W10 |    |W11 |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=0, y=1), 'black_piece_2': Location(x=0, y=3), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=1, y=2), 'black_piece_7': Location(x=1, y=4), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_10': Location(x=4, y=5), 'black_piece_11': Location(x=2, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_1': Location(x=5, y=0), 'white_piece_2': Location(x=5, y=2), 'white_piece_4': Location(x=5, y=6), 'white_piece_5': Location(x=6, y=1), 'white_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=6, y=5), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=7, y=4), 'white_piece_12': Location(x=7, y=6)}
#
#
# White's turn (turn 6):
#
# 0 |    |B1  |    |B2  |    |B3  |    |B4  |
# 1 |    |    |B6  |    |B7  |    |B8  |    |
# 2 |    |B5  |    |    |    |B11 |    |B12 |
# 3 |B9  |    |    |    |W4  |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |W1  |    |W2  |    |    |    |    |    |
# 6 |    |W5  |    |W6  |    |W7  |    |W8  |
# 7 |W9  |    |W10 |    |W11 |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=0, y=1), 'black_piece_2': Location(x=0, y=3), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=1, y=2), 'black_piece_7': Location(x=1, y=4), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_11': Location(x=2, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_1': Location(x=5, y=0), 'white_piece_2': Location(x=5, y=2), 'white_piece_4': Location(x=3, y=4), 'white_piece_5': Location(x=6, y=1), 'white_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=6, y=5), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=7, y=4), 'white_piece_12': Location(x=7, y=6)}
#
#
# Black's turn (turn 7):
#
# 0 |    |B1  |    |B2  |    |B3  |    |B4  |
# 1 |    |    |B6  |    |B7  |    |B8  |    |
# 2 |    |B5  |    |    |    |    |    |B12 |
# 3 |B9  |    |    |    |    |    |    |    |
# 4 |    |    |    |B11 |    |    |    |    |
# 5 |W1  |    |W2  |    |    |    |    |    |
# 6 |    |W5  |    |W6  |    |W7  |    |W8  |
# 7 |W9  |    |W10 |    |W11 |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=0, y=1), 'black_piece_2': Location(x=0, y=3), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=1, y=2), 'black_piece_7': Location(x=1, y=4), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_11': Location(x=4, y=3), 'black_piece_12': Location(x=2, y=7), 'white_piece_1': Location(x=5, y=0), 'white_piece_2': Location(x=5, y=2), 'white_piece_5': Location(x=6, y=1), 'white_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=6, y=5), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=7, y=4), 'white_piece_12': Location(x=7, y=6)}
#
#
# White's turn (turn 8):
#
# 0 |    |B1  |    |B2  |    |B3  |    |B4  |
# 1 |    |    |B6  |    |B7  |    |B8  |    |
# 2 |    |B5  |    |    |    |    |    |B12 |
# 3 |B9  |    |    |    |W2  |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |W1  |    |    |    |    |    |    |    |
# 6 |    |W5  |    |W6  |    |W7  |    |W8  |
# 7 |W9  |    |W10 |    |W11 |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=0, y=1), 'black_piece_2': Location(x=0, y=3), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=1, y=2), 'black_piece_7': Location(x=1, y=4), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_12': Location(x=2, y=7), 'white_piece_1': Location(x=5, y=0), 'white_piece_2': Location(x=3, y=4), 'white_piece_5': Location(x=6, y=1), 'white_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=6, y=5), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=7, y=4), 'white_piece_12': Location(x=7, y=6)}
#
#
# Black's turn (turn 9):
#
# 0 |    |B1  |    |B2  |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |B5  |    |B7  |    |    |    |B12 |
# 3 |B9  |    |    |    |W2  |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |W1  |    |    |    |    |    |    |    |
# 6 |    |W5  |    |W6  |    |W7  |    |W8  |
# 7 |W9  |    |W10 |    |W11 |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=0, y=1), 'black_piece_2': Location(x=0, y=3), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=1, y=2), 'black_piece_7': Location(x=2, y=3), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_12': Location(x=2, y=7), 'white_piece_1': Location(x=5, y=0), 'white_piece_2': Location(x=3, y=4), 'white_piece_5': Location(x=6, y=1), 'white_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=6, y=5), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=7, y=4), 'white_piece_12': Location(x=7, y=6)}
#
#
# White's turn (turn 10):
#
# 0 |    |B1  |    |B2  |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |B5  |    |B7  |    |    |    |B12 |
# 3 |B9  |    |    |    |W2  |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |W1  |    |    |    |    |    |W7  |    |
# 6 |    |W5  |    |W6  |    |    |    |W8  |
# 7 |W9  |    |W10 |    |W11 |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=0, y=1), 'black_piece_2': Location(x=0, y=3), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=1, y=2), 'black_piece_7': Location(x=2, y=3), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_12': Location(x=2, y=7), 'white_piece_1': Location(x=5, y=0), 'white_piece_2': Location(x=3, y=4), 'white_piece_5': Location(x=6, y=1), 'white_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=5, y=6), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=7, y=4), 'white_piece_12': Location(x=7, y=6)}
#
#
# Black's turn (turn 11):
#
# 0 |    |B1  |    |B2  |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |B5  |    |    |    |    |    |B12 |
# 3 |B9  |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |B7  |    |    |
# 5 |W1  |    |    |    |    |    |W7  |    |
# 6 |    |W5  |    |W6  |    |    |    |W8  |
# 7 |W9  |    |W10 |    |W11 |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=0, y=1), 'black_piece_2': Location(x=0, y=3), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=1, y=2), 'black_piece_7': Location(x=4, y=5), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_12': Location(x=2, y=7), 'white_piece_1': Location(x=5, y=0), 'white_piece_5': Location(x=6, y=1), 'white_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=5, y=6), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=7, y=4), 'white_piece_12': Location(x=7, y=6)}
#
#
# White's turn (turn 12):
#
# 0 |    |B1  |    |B2  |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |B5  |    |    |    |    |    |B12 |
# 3 |B9  |    |    |    |W7  |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |W1  |    |    |    |    |    |    |    |
# 6 |    |W5  |    |W6  |    |    |    |W8  |
# 7 |W9  |    |W10 |    |W11 |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=0, y=1), 'black_piece_2': Location(x=0, y=3), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_12': Location(x=2, y=7), 'white_piece_1': Location(x=5, y=0), 'white_piece_5': Location(x=6, y=1), 'white_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=3, y=4), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=7, y=4), 'white_piece_12': Location(x=7, y=6)}
#
#
# Black's turn (turn 13):
#
# 0 |    |    |    |B2  |    |B3  |    |B4  |
# 1 |B1  |    |B6  |    |    |    |B8  |    |
# 2 |    |B5  |    |    |    |    |    |B12 |
# 3 |B9  |    |    |    |W7  |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |W1  |    |    |    |    |    |    |    |
# 6 |    |W5  |    |W6  |    |    |    |W8  |
# 7 |W9  |    |W10 |    |W11 |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=1, y=0), 'black_piece_2': Location(x=0, y=3), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_12': Location(x=2, y=7), 'white_piece_1': Location(x=5, y=0), 'white_piece_5': Location(x=6, y=1), 'white_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=3, y=4), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=7, y=4), 'white_piece_12': Location(x=7, y=6)}
#
#
# White's turn (turn 14):
#
# 0 |    |    |    |B2  |    |B3  |    |B4  |
# 1 |B1  |    |B6  |    |    |    |B8  |    |
# 2 |    |B5  |    |    |    |    |    |B12 |
# 3 |B9  |    |    |    |W7  |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |W1  |    |    |    |    |    |    |    |
# 6 |    |W5  |    |W6  |    |W11 |    |W8  |
# 7 |W9  |    |W10 |    |    |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=1, y=0), 'black_piece_2': Location(x=0, y=3), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_12': Location(x=2, y=7), 'white_piece_1': Location(x=5, y=0), 'white_piece_5': Location(x=6, y=1), 'white_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=3, y=4), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=6, y=5), 'white_piece_12': Location(x=7, y=6)}
#
#
# Black's turn (turn 15):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |B1  |    |B6  |    |B2  |    |B8  |    |
# 2 |    |B5  |    |    |    |    |    |B12 |
# 3 |B9  |    |    |    |W7  |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |W1  |    |    |    |    |    |    |    |
# 6 |    |W5  |    |W6  |    |W11 |    |W8  |
# 7 |W9  |    |W10 |    |    |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=1, y=0), 'black_piece_2': Location(x=1, y=4), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_12': Location(x=2, y=7), 'white_piece_1': Location(x=5, y=0), 'white_piece_5': Location(x=6, y=1), 'white_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=3, y=4), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=6, y=5), 'white_piece_12': Location(x=7, y=6)}
#
#
# White's turn (turn 16):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |B1  |    |B6  |    |B2  |    |B8  |    |
# 2 |    |B5  |    |W7  |    |    |    |B12 |
# 3 |B9  |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |W1  |    |    |    |    |    |    |    |
# 6 |    |W5  |    |W6  |    |W11 |    |W8  |
# 7 |W9  |    |W10 |    |    |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=1, y=0), 'black_piece_2': Location(x=1, y=4), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_12': Location(x=2, y=7), 'white_piece_1': Location(x=5, y=0), 'white_piece_5': Location(x=6, y=1), 'white_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=2, y=3), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=6, y=5), 'white_piece_12': Location(x=7, y=6)}
#
#
# Black's turn (turn 17):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |B1  |    |B6  |    |    |    |B8  |    |
# 2 |    |B5  |    |    |    |    |    |B12 |
# 3 |B9  |    |B2  |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |W1  |    |    |    |    |    |    |    |
# 6 |    |W5  |    |W6  |    |W11 |    |W8  |
# 7 |W9  |    |W10 |    |    |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=1, y=0), 'black_piece_2': Location(x=3, y=2), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_12': Location(x=2, y=7), 'white_piece_1': Location(x=5, y=0), 'white_piece_5': Location(x=6, y=1), 'white_piece_6': Location(x=6, y=3), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=6, y=5), 'white_piece_12': Location(x=7, y=6)}
#
#
# White's turn (turn 18):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |B1  |    |B6  |    |    |    |B8  |    |
# 2 |    |B5  |    |    |    |    |    |B12 |
# 3 |B9  |    |B2  |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |W1  |    |    |    |    |    |W11 |    |
# 6 |    |W5  |    |W6  |    |    |    |W8  |
# 7 |W9  |    |W10 |    |    |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=1, y=0), 'black_piece_2': Location(x=3, y=2), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_12': Location(x=2, y=7), 'white_piece_1': Location(x=5, y=0), 'white_piece_5': Location(x=6, y=1), 'white_piece_6': Location(x=6, y=3), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=5, y=6), 'white_piece_12': Location(x=7, y=6)}
#
#
# Black's turn (turn 19):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |B1  |    |B6  |    |    |    |B8  |    |
# 2 |    |B5  |    |    |    |    |    |B12 |
# 3 |B9  |    |    |    |    |    |    |    |
# 4 |    |B2  |    |    |    |    |    |    |
# 5 |W1  |    |    |    |    |    |W11 |    |
# 6 |    |W5  |    |W6  |    |    |    |W8  |
# 7 |W9  |    |W10 |    |    |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=1, y=0), 'black_piece_2': Location(x=4, y=1), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_12': Location(x=2, y=7), 'white_piece_1': Location(x=5, y=0), 'white_piece_5': Location(x=6, y=1), 'white_piece_6': Location(x=6, y=3), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=5, y=6), 'white_piece_12': Location(x=7, y=6)}
#
#
# White's turn (turn 20):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |B1  |    |B6  |    |    |    |B8  |    |
# 2 |    |B5  |    |    |    |    |    |B12 |
# 3 |B9  |    |W1  |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |W11 |    |
# 6 |    |W5  |    |W6  |    |    |    |W8  |
# 7 |W9  |    |W10 |    |    |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=1, y=0), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_12': Location(x=2, y=7), 'white_piece_1': Location(x=3, y=2), 'white_piece_5': Location(x=6, y=1), 'white_piece_6': Location(x=6, y=3), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=5, y=6), 'white_piece_12': Location(x=7, y=6)}
#
#
# Black's turn (turn 21):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |B1  |    |B6  |    |    |    |B8  |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |B9  |    |    |    |    |    |    |    |
# 4 |    |    |    |B5  |    |    |    |    |
# 5 |    |    |    |    |    |    |W11 |    |
# 6 |    |W5  |    |W6  |    |    |    |W8  |
# 7 |W9  |    |W10 |    |    |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=1, y=0), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=4, y=3), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=6, y=1), 'white_piece_6': Location(x=6, y=3), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=5, y=6), 'white_piece_12': Location(x=7, y=6)}
#
#
# White's turn (turn 22):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |B1  |    |B6  |    |    |    |B8  |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |B9  |    |    |    |    |    |    |    |
# 4 |    |    |    |B5  |    |    |    |    |
# 5 |W5  |    |    |    |    |    |W11 |    |
# 6 |    |    |    |W6  |    |    |    |W8  |
# 7 |W9  |    |W10 |    |    |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=1, y=0), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=4, y=3), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=5, y=0), 'white_piece_6': Location(x=6, y=3), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=5, y=6), 'white_piece_12': Location(x=7, y=6)}
#
#
# Black's turn (turn 23):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |B1  |    |    |    |    |    |B12 |
# 3 |B9  |    |    |    |    |    |    |    |
# 4 |    |    |    |B5  |    |    |    |    |
# 5 |W5  |    |    |    |    |    |W11 |    |
# 6 |    |    |    |W6  |    |    |    |W8  |
# 7 |W9  |    |W10 |    |    |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=2, y=1), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=4, y=3), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=5, y=0), 'white_piece_6': Location(x=6, y=3), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=5, y=6), 'white_piece_12': Location(x=7, y=6)}
#
#
# White's turn (turn 24):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |B1  |    |    |    |    |    |B12 |
# 3 |B9  |    |    |    |    |    |    |    |
# 4 |    |    |    |B5  |    |    |    |    |
# 5 |W5  |    |W6  |    |    |    |W11 |    |
# 6 |    |    |    |    |    |    |    |W8  |
# 7 |W9  |    |W10 |    |    |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=2, y=1), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=4, y=3), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=5, y=0), 'white_piece_6': Location(x=5, y=2), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=5, y=6), 'white_piece_12': Location(x=7, y=6)}
#
#
# Black's turn (turn 25):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |B1  |    |    |    |    |    |B12 |
# 3 |B9  |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |W5  |    |    |    |    |    |W11 |    |
# 6 |    |B5  |    |    |    |    |    |W8  |
# 7 |W9  |    |W10 |    |    |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=2, y=1), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_5': Location(x=6, y=1), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=5, y=0), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=7, y=0), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=5, y=6), 'white_piece_12': Location(x=7, y=6)}
#
#
# White's turn (turn 26):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |B1  |    |    |    |    |    |B12 |
# 3 |B9  |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |W5  |    |W9  |    |    |    |W11 |    |
# 6 |    |    |    |    |    |    |    |W8  |
# 7 |    |    |W10 |    |    |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=2, y=1), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=5, y=0), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=5, y=2), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=5, y=6), 'white_piece_12': Location(x=7, y=6)}
#
#
# Black's turn (turn 27):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |B9  |    |B1  |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |W5  |    |W9  |    |    |    |W11 |    |
# 6 |    |    |    |    |    |    |    |W8  |
# 7 |    |    |W10 |    |    |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=3, y=2), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=5, y=0), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=5, y=2), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=5, y=6), 'white_piece_12': Location(x=7, y=6)}
#
#
# White's turn (turn 28):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |B9  |    |B1  |    |    |    |    |    |
# 4 |    |W9  |    |    |    |    |    |    |
# 5 |W5  |    |    |    |    |    |W11 |    |
# 6 |    |    |    |    |    |    |    |W8  |
# 7 |    |    |W10 |    |    |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=3, y=2), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=3, y=0), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=5, y=0), 'white_piece_8': Location(x=6, y=7), 'white_piece_9': Location(x=4, y=1), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=5, y=6), 'white_piece_12': Location(x=7, y=6)}
#
#
# Black's turn (turn 29):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |B1  |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |W5  |    |B9  |    |    |    |W11 |    |
# 6 |    |    |    |    |    |    |    |W8  |
# 7 |    |    |W10 |    |    |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=3, y=2), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=5, y=2), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=5, y=0), 'white_piece_8': Location(x=6, y=7), 'white_piece_10': Location(x=7, y=2), 'white_piece_11': Location(x=5, y=6), 'white_piece_12': Location(x=7, y=6)}
#
#
# White's turn (turn 30):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |B1  |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |W5  |    |B9  |    |    |    |W11 |    |
# 6 |    |    |    |W10 |    |    |    |W8  |
# 7 |    |    |    |    |    |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=3, y=2), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_9': Location(x=5, y=2), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=5, y=0), 'white_piece_8': Location(x=6, y=7), 'white_piece_10': Location(x=6, y=3), 'white_piece_11': Location(x=5, y=6), 'white_piece_12': Location(x=7, y=6)}
#
#
# Black's turn (turn 31):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |B1  |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |W5  |    |    |    |    |    |W11 |    |
# 6 |    |    |    |    |    |    |    |W8  |
# 7 |    |    |    |    |KB9 |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=3, y=2), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=5, y=0), 'white_piece_8': Location(x=6, y=7), 'white_piece_11': Location(x=5, y=6), 'white_piece_12': Location(x=7, y=6), 'king_black_piece_9': Location(x=7, y=4)}
#
#
# White's turn (turn 32):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |B1  |    |    |    |    |    |
# 4 |    |    |    |    |    |W11 |    |    |
# 5 |W5  |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |W8  |
# 7 |    |    |    |    |KB9 |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=3, y=2), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=5, y=0), 'white_piece_8': Location(x=6, y=7), 'white_piece_11': Location(x=4, y=5), 'white_piece_12': Location(x=7, y=6), 'king_black_piece_9': Location(x=7, y=4)}
#
#
# Black's turn (turn 33):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |B1  |    |W11 |    |    |
# 5 |W5  |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |W8  |
# 7 |    |    |    |    |KB9 |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=4, y=3), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=5, y=0), 'white_piece_8': Location(x=6, y=7), 'white_piece_11': Location(x=4, y=5), 'white_piece_12': Location(x=7, y=6), 'king_black_piece_9': Location(x=7, y=4)}
#
#
# White's turn (turn 34):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |W5  |    |B1  |    |W11 |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |W8  |
# 7 |    |    |    |    |KB9 |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=4, y=3), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=4, y=1), 'white_piece_8': Location(x=6, y=7), 'white_piece_11': Location(x=4, y=5), 'white_piece_12': Location(x=7, y=6), 'king_black_piece_9': Location(x=7, y=4)}
#
#
# Black's turn (turn 35):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |W5  |    |    |    |W11 |    |    |
# 5 |    |    |B1  |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |W8  |
# 7 |    |    |    |    |KB9 |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=5, y=2), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=4, y=1), 'white_piece_8': Location(x=6, y=7), 'white_piece_11': Location(x=4, y=5), 'white_piece_12': Location(x=7, y=6), 'king_black_piece_9': Location(x=7, y=4)}
#
#
# White's turn (turn 36):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |W11 |    |    |    |
# 4 |    |W5  |    |    |    |    |    |    |
# 5 |    |    |B1  |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |W8  |
# 7 |    |    |    |    |KB9 |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=5, y=2), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=4, y=1), 'white_piece_8': Location(x=6, y=7), 'white_piece_11': Location(x=3, y=4), 'white_piece_12': Location(x=7, y=6), 'king_black_piece_9': Location(x=7, y=4)}
#
#
# Black's turn (turn 37):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |W11 |    |    |    |
# 4 |    |W5  |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |B1  |    |    |    |    |    |W8  |
# 7 |    |    |    |    |KB9 |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=6, y=1), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=4, y=1), 'white_piece_8': Location(x=6, y=7), 'white_piece_11': Location(x=3, y=4), 'white_piece_12': Location(x=7, y=6), 'king_black_piece_9': Location(x=7, y=4)}
#
#
# White's turn (turn 38):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |W5  |    |W11 |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |B1  |    |    |    |    |    |W8  |
# 7 |    |    |    |    |KB9 |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_1': Location(x=6, y=1), 'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=3, y=2), 'white_piece_8': Location(x=6, y=7), 'white_piece_11': Location(x=3, y=4), 'white_piece_12': Location(x=7, y=6), 'king_black_piece_9': Location(x=7, y=4)}
#
#
# Black's turn (turn 39):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |W5  |    |W11 |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |W8  |
# 7 |KB1 |    |    |    |KB9 |    |W12 |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=3, y=2), 'white_piece_8': Location(x=6, y=7), 'white_piece_11': Location(x=3, y=4), 'white_piece_12': Location(x=7, y=6), 'king_black_piece_9': Location(x=7, y=4), 'king_black_piece_1': Location(x=7, y=0)}
#
#
# White's turn (turn 40):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |W5  |    |W11 |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |W12 |    |W8  |
# 7 |KB1 |    |    |    |KB9 |    |    |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=3, y=2), 'white_piece_8': Location(x=6, y=7), 'white_piece_11': Location(x=3, y=4), 'white_piece_12': Location(x=6, y=5), 'king_black_piece_9': Location(x=7, y=4), 'king_black_piece_1': Location(x=7, y=0)}
#
#
# Black's turn (turn 41):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |W5  |    |W11 |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |KB9 |    |
# 6 |    |    |    |    |    |    |    |W8  |
# 7 |KB1 |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=3, y=2), 'white_piece_8': Location(x=6, y=7), 'white_piece_11': Location(x=3, y=4), 'king_black_piece_9': Location(x=5, y=6), 'king_black_piece_1': Location(x=7, y=0)}
#
#
# White's turn (turn 42):
#
# 0 |    |    |    |    |    |B3  |    |B4  |
# 1 |    |    |B6  |    |    |    |B8  |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |W5  |    |W11 |    |    |    |
# 4 |    |    |    |    |    |W8  |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |KB1 |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_3': Location(x=0, y=5), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=3, y=2), 'white_piece_8': Location(x=4, y=5), 'white_piece_11': Location(x=3, y=4), 'king_black_piece_1': Location(x=7, y=0)}
#
#
# Black's turn (turn 43):
#
# 0 |    |    |    |    |    |    |    |B4  |
# 1 |    |    |B6  |    |B3  |    |B8  |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |W5  |    |W11 |    |    |    |
# 4 |    |    |    |    |    |W8  |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |KB1 |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_3': Location(x=1, y=4), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=3, y=2), 'white_piece_8': Location(x=4, y=5), 'white_piece_11': Location(x=3, y=4), 'king_black_piece_1': Location(x=7, y=0)}
#
#
# White's turn (turn 44):
#
# 0 |    |    |    |    |    |    |    |B4  |
# 1 |    |    |B6  |    |B3  |    |B8  |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |W5  |    |W11 |    |W8  |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |KB1 |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_3': Location(x=1, y=4), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_12': Location(x=2, y=7), 'white_piece_5': Location(x=3, y=2), 'white_piece_8': Location(x=3, y=6), 'white_piece_11': Location(x=3, y=4), 'king_black_piece_1': Location(x=7, y=0)}
#
#
# Black's turn (turn 45):
#
# 0 |    |    |    |    |    |    |    |B4  |
# 1 |    |    |B6  |    |B3  |    |B8  |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |W5  |    |W11 |    |    |    |
# 4 |    |    |    |    |    |B12 |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |KB1 |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_3': Location(x=1, y=4), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_12': Location(x=4, y=5), 'white_piece_5': Location(x=3, y=2), 'white_piece_11': Location(x=3, y=4), 'king_black_piece_1': Location(x=7, y=0)}
#
#
# White's turn (turn 46):
#
# 0 |    |    |    |    |    |    |    |B4  |
# 1 |    |    |B6  |    |B3  |    |B8  |    |
# 2 |    |W5  |    |    |    |    |    |    |
# 3 |    |    |    |    |W11 |    |    |    |
# 4 |    |    |    |    |    |B12 |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |KB1 |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_3': Location(x=1, y=4), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=1, y=2), 'black_piece_8': Location(x=1, y=6), 'black_piece_12': Location(x=4, y=5), 'white_piece_5': Location(x=2, y=1), 'white_piece_11': Location(x=3, y=4), 'king_black_piece_1': Location(x=7, y=0)}
#
#
# Black's turn (turn 47):
#
# 0 |    |    |    |    |    |    |    |B4  |
# 1 |    |    |    |    |B3  |    |B8  |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |B6  |    |    |    |W11 |    |    |    |
# 4 |    |    |    |    |    |B12 |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |KB1 |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_3': Location(x=1, y=4), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=3, y=0), 'black_piece_8': Location(x=1, y=6), 'black_piece_12': Location(x=4, y=5), 'white_piece_11': Location(x=3, y=4), 'king_black_piece_1': Location(x=7, y=0)}
#
#
# White's turn (turn 48):
#
# 0 |    |    |    |    |    |    |    |B4  |
# 1 |    |    |    |    |B3  |    |B8  |    |
# 2 |    |    |    |W11 |    |    |    |    |
# 3 |B6  |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |B12 |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |KB1 |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_3': Location(x=1, y=4), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=3, y=0), 'black_piece_8': Location(x=1, y=6), 'black_piece_12': Location(x=4, y=5), 'white_piece_11': Location(x=2, y=3), 'king_black_piece_1': Location(x=7, y=0)}
#
#
# Black's turn (turn 49):
#
# 0 |    |    |    |    |    |    |    |B4  |
# 1 |    |    |    |    |    |    |B8  |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |B6  |    |B3  |    |    |    |    |    |
# 4 |    |    |    |    |    |B12 |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |KB1 |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# {'black_piece_3': Location(x=3, y=2), 'black_piece_4': Location(x=0, y=7), 'black_piece_6': Location(x=3, y=0), 'black_piece_8': Location(x=1, y=6), 'black_piece_12': Location(x=4, y=5), 'king_black_piece_1': Location(x=7, y=0)}
# Black wins!
# Board score: -1000
# ('Black', 49)

# %% [markdown]
# ## Play multiple games with the IntelligentAgent playing against the NaiveAgent
# ### Check the results including how many turns does it take for the IntelligentAgent to win? How does changing the depth of the minimax algorithm change this?

# %%
# Out of 10 games, how many turns does it take for the IntelligentAgent to win with a minimax depth of 3? How long does that game take?

Game().run_ia_multiple_games(board_depth=3, num_games=10)
# Out:
# Playing Game 1:
# Black wins!
#
#
# Playing Game 2:
# No possible moves for white, black wins
# Black wins!
#
#
# Playing Game 3:
# Black wins!
#
#
# Playing Game 4:
# Black wins!
#
#
# Playing Game 5:
# Black wins!
#
#
# Playing Game 6:
# Black wins!
#
#
# Playing Game 7:
# Black wins!
#
#
# Playing Game 8:
# Black wins!
#
#
# Playing Game 9:
# Black wins!
#
#
# Playing Game 10:
# Black wins!
# Black wins: 10
# White wins: 0
# Average game duration: 10.78 seconds
# Average number of turns to win: 53.40

# %%
# Out of 10 games, how many turns does it take for the IntelligentAgent to win with a minimax depth of 2? How long does that game take?

Game().run_ia_multiple_games(board_depth=2, num_games=10)
# Out:
# Playing Game 1:
# Black wins!
#
#
# Playing Game 2:
# Black wins!
#
#
# Playing Game 3:
# Black wins!
#
#
# Playing Game 4:
# Black wins!
#
#
# Playing Game 5:
# No possible moves for white, black wins
# Black wins!
#
#
# Playing Game 6:
# Black wins!
#
#
# Playing Game 7:
# Black wins!
#
#
# Playing Game 8:
# Black wins!
#
#
# Playing Game 9:
# Black wins!
#
#
# Playing Game 10:
# Black wins!
# Black wins: 10
# White wins: 0
# Average game duration: 1.85 seconds
# Average number of turns to win: 53.20

# %%
# Out of 10 games, how many turns does it take for the IntelligentAgent to win with a minimax depth of 4? How long does that game take?

Game().run_ia_multiple_games(board_depth=4, num_games=10)
# Out:
# Playing Game 1:
# No possible moves for white, black wins
# Black wins!
#
#
# Playing Game 2:
# Black wins!
#
#
# Playing Game 3:
# Black wins!
#
#
# Playing Game 4:
# No possible moves for white, black wins
# Black wins!
#
#
# Playing Game 5:
# Black wins!
#
#
# Playing Game 6:
# Black wins!
#
#
# Playing Game 7:
# Black wins!
#
#
# Playing Game 8:
# No possible moves for white, black wins
# Black wins!
#
#
# Playing Game 9:
# Black wins!
#
#
# Playing Game 10:
# Black wins!
# Black wins: 10
# White wins: 0
# Average game duration: 38.24 seconds
# Average number of turns to win: 46.30

# %%
# Out of 10 games, how many turns does it take for the IntelligentAgent to win with a minimax depth of 5? How long does that game take?

Game().run_ia_multiple_games(board_depth=5, num_games=10)
# Out:
# Playing Game 1:
# Black wins!
#
#
# Playing Game 2:
# Black wins!
#
#
# Playing Game 3:
# Black wins!
#
#
# Playing Game 4:
# No possible moves for white, black wins
# Black wins!
#
#
# Playing Game 5:
# Black wins!
#
#
# Playing Game 6:
# Black wins!
#
#
# Playing Game 7:
# No possible moves for white, black wins
# Black wins!
#
#
# Playing Game 8:
# Black wins!
#
#
# Playing Game 9:
# Black wins!
#
#
# Playing Game 10:
# Black wins!
# Black wins: 10
# White wins: 0
# Average game duration: 183.17 seconds
# Average number of turns to win: 43.10
