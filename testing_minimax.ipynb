# %%
from typing import List
from enum import Enum, auto
import numpy as np
from copy import deepcopy
import time



from Location import Location
from CheckerBoard import CheckerBoard
from NaiveAgent import NaiveAgent
from Move import Move
from Game import Game
from IntelligentAgent import IntelligentAgent

# %% [markdown]
# ### Testing individual board states on the minimax algorithm

# %%
## To see the minimax algorithm visualized, see diagram
board_state = {'black_piece_3': Location(x=2, y=5), 
               'black_piece_12': Location(x=2, y=7), 
               'white_piece_6': Location(x=4, y=3), 
               'white_piece_11': Location(x=7, y=4), 
               }

CheckerBoard.visualize_piece_numbers(board_state)

color = 'black'
intelligent_agent = IntelligentAgent(color, board_state)
intelligent_agent.minimax_try2(board_state=board_state, depth=4, is_maximizing=False, show_minimax_boards=True)
# Out:
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |B3  |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |W6  |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# The board state is: {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 4
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |B3  |    |    |    |
# 4 |    |    |    |W6  |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=3, y=4)
# The board state is: {'black_piece_3': Location(x=3, y=4), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 3
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |W6  |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# white_piece_6 can move from Location(x=4, y=3) to Location(x=2, y=5)
# and can capture black_piece_3
# The board state is: {'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=2, y=5), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |W6  |    |    |
# 3 |    |    |    |    |    |    |B12 |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=3, y=6)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=2, y=5)
# and can capture black_piece_3
# The board state is: {'black_piece_12': Location(x=3, y=6), 'white_piece_6': Location(x=2, y=5), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |W6  |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |B12 |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=3, y=6)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=1, y=4)
# and can capture black_piece_3
# The board state is: {'black_piece_12': Location(x=3, y=6), 'white_piece_6': Location(x=1, y=4), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 0
# The results of minimax are: (1, None)
# -inf 1
# The maxEval is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |W6  |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |B12 |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=3, y=6)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=1, y=6)
# and can capture black_piece_3
# The board state is: {'black_piece_12': Location(x=3, y=6), 'white_piece_6': Location(x=1, y=6), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 0
# The results of minimax are: (1, None)
# 1 1
# The maxEval is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |W6  |    |    |
# 3 |    |    |    |    |    |    |B12 |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |W11 |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=3, y=6)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=2, y=5)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=3)
# and can capture black_piece_3
# The board state is: {'black_piece_12': Location(x=3, y=6), 'white_piece_6': Location(x=2, y=5), 'white_piece_11': Location(x=6, y=3)}
# The depth is: 0
# The results of minimax are: (1, None)
# 1 1
# The maxEval is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |W6  |    |    |
# 3 |    |    |    |    |    |    |B12 |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |W11 |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=3, y=6)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=2, y=5)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=5)
# and can capture black_piece_3
# The board state is: {'black_piece_12': Location(x=3, y=6), 'white_piece_6': Location(x=2, y=5), 'white_piece_11': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (1, None)
# 1 1
# The maxEval is: 1
# The results of minimax are: (1, {'black_piece_12': Location(x=3, y=6), 'white_piece_6': Location(x=1, y=4), 'white_piece_11': Location(x=7, y=4)})
# inf 1
# The minEval is: 1
# The results of minimax are: (1, {'black_piece_12': Location(x=3, y=6), 'white_piece_6': Location(x=2, y=5), 'white_piece_11': Location(x=7, y=4)})
# -inf 1
# The maxEval is: 1
# The results of minimax are: (1, {'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=2, y=5), 'white_piece_11': Location(x=7, y=4)})
# inf 1
# The minEval is: 1
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |    |    |B3  |    |
# 4 |    |    |    |W6  |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=3, y=6)
# The board state is: {'black_piece_3': Location(x=3, y=6), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 3
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |W6  |    |    |    |B3  |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=3, y=6)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=2)
# The board state is: {'black_piece_3': Location(x=3, y=6), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |W6  |    |    |    |    |    |
# 4 |    |    |    |    |    |B3  |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=5)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=2)
# The board state is: {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |W6  |    |    |    |    |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |B3  |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=5)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=2, y=1)
# The board state is: {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=2, y=1), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 0
# The results of minimax are: (0, None)
# -inf 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |W6  |    |    |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |B3  |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=5)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=2, y=3)
# The board state is: {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=2, y=3), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |W6  |    |    |    |    |    |
# 4 |    |    |    |    |    |B3  |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |W11 |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=5)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=2)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=3)
# The board state is: {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=6, y=3)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |W6  |    |    |    |    |    |
# 4 |    |    |    |    |    |B3  |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |W11 |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=5)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=2)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=5)
# The board state is: {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# The results of minimax are: (0, {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=2, y=1), 'white_piece_11': Location(x=7, y=4)})
# inf 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |W6  |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |B3  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=7)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=2)
# The board state is: {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |W6  |    |    |    |    |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |B3  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=7)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=2, y=1)
# The board state is: {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=2, y=1), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 0
# The results of minimax are: (0, None)
# -inf 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |W6  |    |    |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |B3  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=7)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=2, y=3)
# The board state is: {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=2, y=3), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |W6  |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |B3  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |W11 |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=7)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=2)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=3)
# The board state is: {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=6, y=3)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |W6  |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |B3  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |W11 |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=7)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=2)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=5)
# The board state is: {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# The results of minimax are: (0, {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=2, y=1), 'white_piece_11': Location(x=7, y=4)})
# 0 0
# The minEval is: 0
# The results of minimax are: (0, {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=7, y=4)})
# -inf 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |W6  |    |B3  |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=3, y=6)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=4)
# The board state is: {'black_piece_3': Location(x=3, y=6), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=4), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |W6  |    |    |    |
# 4 |    |    |    |    |    |B3  |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=5)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=4)
# The board state is: {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=4), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |W6  |    |    |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |B3  |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=5)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=2, y=3)
# The board state is: {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=2, y=3), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 0
# The results of minimax are: (0, None)
# -inf 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |W6  |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |B3  |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=5)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=2, y=5)
# The board state is: {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=2, y=5), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |W6  |    |    |    |
# 4 |    |    |    |    |    |B3  |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |W11 |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=5)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=4)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=3)
# The board state is: {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=4), 'white_piece_11': Location(x=6, y=3)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |W6  |    |    |    |
# 4 |    |    |    |    |    |B3  |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |W11 |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=5)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=4)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=5)
# The board state is: {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=4), 'white_piece_11': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# The results of minimax are: (0, {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=2, y=3), 'white_piece_11': Location(x=7, y=4)})
# inf 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |W6  |    |    |    |
# 4 |    |    |    |    |    |    |    |B3  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=7)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=4)
# The board state is: {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=4), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |W6  |    |    |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |B3  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=7)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=2, y=3)
# The board state is: {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=2, y=3), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 0
# The results of minimax are: (0, None)
# -inf 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |W6  |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |B3  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=7)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=2, y=5)
# The board state is: {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=2, y=5), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |W6  |    |    |    |
# 4 |    |    |    |    |    |    |    |B3  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |W11 |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=7)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=4)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=3)
# The board state is: {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=4), 'white_piece_11': Location(x=6, y=3)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |W6  |    |    |    |
# 4 |    |    |    |    |    |    |    |B3  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |W11 |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=7)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=4)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=5)
# The board state is: {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=4), 'white_piece_11': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# The results of minimax are: (0, {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=2, y=3), 'white_piece_11': Location(x=7, y=4)})
# 0 0
# The minEval is: 0
# The results of minimax are: (0, {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=4), 'white_piece_11': Location(x=7, y=4)})
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |    |    |B3  |    |
# 4 |    |    |    |W6  |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |W11 |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=3, y=6)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=3)
# The board state is: {'black_piece_3': Location(x=3, y=6), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=6, y=3)}
# The depth is: 2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |W6  |    |B3  |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |W11 |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=5)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=3)
# The board state is: {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=6, y=3)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |W6  |    |    |    |    |    |
# 4 |    |    |    |    |    |B3  |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |W11 |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=5)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=2)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=3)
# The board state is: {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=6, y=3)}
# The depth is: 0
# The results of minimax are: (0, None)
# -inf 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |W6  |    |    |    |
# 4 |    |    |    |    |    |B3  |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |W11 |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=5)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=4)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=3)
# The board state is: {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=4), 'white_piece_11': Location(x=6, y=3)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |W6  |    |B3  |    |    |
# 5 |    |    |W11 |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=5)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=5, y=2)
# The board state is: {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=5, y=2)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |W6  |    |B3  |    |    |
# 5 |    |    |    |    |W11 |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=5)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=5, y=4)
# The board state is: {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=5, y=4)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# The results of minimax are: (0, {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=6, y=3)})
# inf 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |W6  |    |    |    |B3  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |W11 |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=7)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=3)
# The board state is: {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=6, y=3)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |W6  |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |B3  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |W11 |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=7)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=2)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=3)
# The board state is: {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=6, y=3)}
# The depth is: 0
# The results of minimax are: (0, None)
# -inf 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |W6  |    |    |    |
# 4 |    |    |    |    |    |    |    |B3  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |W11 |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=7)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=4)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=3)
# The board state is: {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=4), 'white_piece_11': Location(x=6, y=3)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |W6  |    |    |    |B3  |
# 5 |    |    |W11 |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=7)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=5, y=2)
# The board state is: {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=5, y=2)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |W6  |    |    |    |B3  |
# 5 |    |    |    |    |W11 |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=7)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=5, y=4)
# The board state is: {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=5, y=4)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# The results of minimax are: (0, {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=6, y=3)})
# 0 0
# The minEval is: 0
# The results of minimax are: (0, {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=6, y=3)})
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |    |    |B3  |    |
# 4 |    |    |    |W6  |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |W11 |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=3, y=6)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=5)
# The board state is: {'black_piece_3': Location(x=3, y=6), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=6, y=5)}
# The depth is: 2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |W6  |    |B3  |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |W11 |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=5)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=5)
# The board state is: {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=6, y=5)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |W6  |    |    |    |    |    |
# 4 |    |    |    |    |    |B3  |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |W11 |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=5)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=2)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=5)
# The board state is: {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# -inf 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |W6  |    |    |    |
# 4 |    |    |    |    |    |B3  |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |W11 |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=5)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=4)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=5)
# The board state is: {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=4), 'white_piece_11': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |W6  |    |B3  |    |    |
# 5 |    |    |    |    |W11 |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=5)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=5, y=4)
# The board state is: {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=5, y=4)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |W6  |    |B3  |    |    |
# 5 |    |    |    |    |    |    |W11 |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=5)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=5, y=6)
# The board state is: {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=5, y=6)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# The results of minimax are: (0, {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=6, y=5)})
# inf 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |W6  |    |    |    |B3  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |W11 |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=7)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=5)
# The board state is: {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=6, y=5)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |W6  |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |B3  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |W11 |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=7)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=2)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=5)
# The board state is: {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# -inf 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |W6  |    |    |    |
# 4 |    |    |    |    |    |    |    |B3  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |W11 |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=7)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=4)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=5)
# The board state is: {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=4), 'white_piece_11': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |W6  |    |    |    |B3  |
# 5 |    |    |    |    |W11 |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=7)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=5, y=4)
# The board state is: {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=5, y=4)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |B12 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |W6  |    |    |    |B3  |
# 5 |    |    |    |    |    |    |W11 |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=4, y=7)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=5, y=6)
# The board state is: {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=5, y=6)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# The results of minimax are: (0, {'black_piece_3': Location(x=4, y=7), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=6, y=5)})
# 0 0
# The minEval is: 0
# The results of minimax are: (0, {'black_piece_3': Location(x=4, y=5), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=6, y=5)})
# 0 0
# The maxEval is: 0
# The results of minimax are: (0, {'black_piece_3': Location(x=3, y=6), 'black_piece_12': Location(x=2, y=7), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=7, y=4)})
# 1 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |B3  |    |    |
# 3 |    |    |    |    |    |    |B12 |    |
# 4 |    |    |    |W6  |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=3, y=6)
# The board state is: {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=3, y=6), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 3
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |B3  |    |    |
# 3 |    |    |W6  |    |    |    |B12 |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=3, y=6)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=2)
# The board state is: {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=3, y=6), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |W6  |    |B3  |    |B12 |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=3, y=4)
# black_piece_12 can move from Location(x=2, y=7) to Location(x=3, y=6)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=2)
# The board state is: {'black_piece_3': Location(x=3, y=4), 'black_piece_12': Location(x=3, y=6), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=7, y=4)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |W6  |    |    |    |    |    |    |
# 3 |    |    |    |    |B3  |    |B12 |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |W11 |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=3, y=4)
# black_piece_12 can move from Location(x=2, y=7) to Location(x=3, y=6)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=2, y=1)
# The board state is: {'black_piece_3': Location(x=3, y=4), 'black_piece_12': Location(x=3, y=6), 'white_piece_6': Location(x=2, y=1), 'white_piece_11': Location(x=7, y=4)}
# ...
# 2 |    |    |    |    |    |B3  |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |W6  |    |    |    |B12 |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |W11 |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=4, y=7)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=3)
# The board state is: {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=4, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=6, y=3)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |B3  |    |    |
# 3 |    |    |W6  |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |B12 |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |W11 |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=4, y=7)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=2)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=3)
# The board state is: {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=4, y=7), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=6, y=3)}
# The depth is: 0
# The results of minimax are: (0, None)
# -inf 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |B3  |    |    |
# 3 |    |    |    |    |W6  |    |    |    |
# 4 |    |    |    |    |    |    |    |B12 |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |W11 |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=4, y=7)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=4)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=3)
# The board state is: {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=4, y=7), 'white_piece_6': Location(x=3, y=4), 'white_piece_11': Location(x=6, y=3)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |B3  |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |W6  |    |    |    |B12 |
# 5 |    |    |W11 |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=4, y=7)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=5, y=2)
# The board state is: {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=4, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=5, y=2)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |B3  |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |W6  |    |    |    |B12 |
# 5 |    |    |    |    |W11 |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=4, y=7)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=5, y=4)
# The board state is: {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=4, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=5, y=4)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# The results of minimax are: (0, {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=4, y=7), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=6, y=3)})
# 0 0
# The minEval is: 0
# The results of minimax are: (0, {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=4, y=5), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=6, y=3)})
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |B3  |    |    |
# 3 |    |    |    |    |    |    |B12 |    |
# 4 |    |    |    |W6  |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |W11 |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=3, y=6)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=5)
# The board state is: {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=3, y=6), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=6, y=5)}
# The depth is: 2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |B3  |    |B12 |    |
# 4 |    |    |    |W6  |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |W11 |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_3 can move from Location(x=2, y=5) to Location(x=3, y=4)
# black_piece_12 can move from Location(x=2, y=7) to Location(x=3, y=6)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=5)
# The board state is: {'black_piece_3': Location(x=3, y=4), 'black_piece_12': Location(x=3, y=6), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=6, y=5)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |W6  |    |    |
# 3 |    |    |    |    |    |    |B12 |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |W11 |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=3, y=6)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=2, y=5)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=5)
# and can capture black_piece_3
# The board state is: {'black_piece_12': Location(x=3, y=6), 'white_piece_6': Location(x=2, y=5), 'white_piece_11': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (1, None)
# -inf 1
# The maxEval is: 1
# The results of minimax are: (1, {'black_piece_12': Location(x=3, y=6), 'white_piece_6': Location(x=2, y=5), 'white_piece_11': Location(x=6, y=5)})
# inf 1
# The minEval is: 1
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |B3  |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |W6  |    |B12 |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |W11 |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=4, y=5)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=5)
# The board state is: {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=4, y=5), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=6, y=5)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |B3  |    |    |
# 3 |    |    |W6  |    |    |    |    |    |
# 4 |    |    |    |    |    |B12 |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |W11 |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=4, y=5)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=2)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=5)
# The board state is: {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=4, y=5), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# -inf 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |B3  |    |    |
# 3 |    |    |    |    |W6  |    |    |    |
# 4 |    |    |    |    |    |B12 |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |W11 |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=4, y=5)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=4)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=5)
# The board state is: {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=4, y=5), 'white_piece_6': Location(x=3, y=4), 'white_piece_11': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |B3  |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |W6  |    |B12 |    |    |
# 5 |    |    |    |    |W11 |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=4, y=5)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=5, y=4)
# The board state is: {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=4, y=5), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=5, y=4)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |B3  |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |W6  |    |B12 |    |    |
# 5 |    |    |    |    |    |    |W11 |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=4, y=5)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=5, y=6)
# The board state is: {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=4, y=5), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=5, y=6)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# The results of minimax are: (0, {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=4, y=5), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=6, y=5)})
# 1 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |B3  |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |W6  |    |    |    |B12 |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |W11 |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=4, y=7)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=5)
# The board state is: {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=4, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=6, y=5)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |B3  |    |    |
# 3 |    |    |W6  |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |B12 |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |W11 |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=4, y=7)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=2)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=5)
# The board state is: {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=4, y=7), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# -inf 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |B3  |    |    |
# 3 |    |    |    |    |W6  |    |    |    |
# 4 |    |    |    |    |    |    |    |B12 |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |W11 |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=4, y=7)
# white_piece_6 can move from Location(x=4, y=3) to Location(x=3, y=4)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=6, y=5)
# The board state is: {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=4, y=7), 'white_piece_6': Location(x=3, y=4), 'white_piece_11': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |B3  |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |W6  |    |    |    |B12 |
# 5 |    |    |    |    |W11 |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=4, y=7)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=5, y=4)
# The board state is: {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=4, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=5, y=4)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |B3  |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |W6  |    |    |    |B12 |
# 5 |    |    |    |    |    |    |W11 |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_12 can move from Location(x=2, y=7) to Location(x=4, y=7)
# white_piece_11 can move from Location(x=7, y=4) to Location(x=5, y=6)
# The board state is: {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=4, y=7), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=5, y=6)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The maxEval is: 0
# The results of minimax are: (0, {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=4, y=7), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=6, y=5)})
# 0 0
# The minEval is: 0
# The results of minimax are: (0, {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=4, y=5), 'white_piece_6': Location(x=4, y=3), 'white_piece_11': Location(x=6, y=5)})
# 0 0
# The maxEval is: 0
# The results of minimax are: (0, {'black_piece_3': Location(x=2, y=5), 'black_piece_12': Location(x=3, y=6), 'white_piece_6': Location(x=3, y=2), 'white_piece_11': Location(x=7, y=4)})
# 0 0
# The minEval is: 0
# (0,
#  {'black_piece_3': Location(x=3, y=6),
#   'black_piece_12': Location(x=2, y=7),
#   'white_piece_6': Location(x=4, y=3),
#   'white_piece_11': Location(x=7, y=4)})

# %% [markdown]
# ##### try a different board state:
#
# See diagram2 for the minimax algorithm visualized

# %%
board_state = {'king_black_piece_2': Location(x=5, y=2), 
               'king_white_piece_12': Location(x=7, y=6)}

print('Initial board state:')
CheckerBoard.visualize_piece_numbers(board_state)

color = 'black'
intelligent_agent = IntelligentAgent(color, board_state)
# intelligent_agent.make_intelligent_move(board_state', 'depth', and 'is_maximizing)
best_move = intelligent_agent.minimax_try2(board_state=board_state, depth=3, is_maximizing=False, show_minimax_boards=True) # True for white, False for black
# Out:
# Initial board state:
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |KB2 |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |KW12|    |
#     0    1    2    3    4    5    6    7
# The board state is: {'king_black_piece_2': Location(x=5, y=2), 'king_white_piece_12': Location(x=7, y=6)}
# The depth is: 3
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |KB2 |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |KW12|    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=6, y=1)
# The board state is: {'king_black_piece_2': Location(x=6, y=1), 'king_white_piece_12': Location(x=7, y=6)}
# The depth is: 2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |KB2 |    |    |    |KW12|    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=6, y=1)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=5)
# The board state is: {'king_black_piece_2': Location(x=6, y=1), 'king_white_piece_12': Location(x=6, y=5)}
# The depth is: 1
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |KW12|    |    |
# 7 |KB2 |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=7, y=0)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=5)
# The board state is: {'king_black_piece_2': Location(x=7, y=0), 'king_white_piece_12': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# inf 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |KW12|    |    |
# 7 |    |    |KB2 |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=7, y=2)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=5)
# The board state is: {'king_black_piece_2': Location(x=7, y=2), 'king_white_piece_12': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |KB2 |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |KW12|    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=5, y=0)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=5)
# The board state is: {'king_black_piece_2': Location(x=5, y=0), 'king_white_piece_12': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |KB2 |    |    |    |    |    |
# 6 |    |    |    |    |    |KW12|    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=5)
# The board state is: {'king_black_piece_2': Location(x=5, y=2), 'king_white_piece_12': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# The results of minimax are: (0, {'king_black_piece_2': Location(x=7, y=0), 'king_white_piece_12': Location(x=6, y=5)})
# -inf 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |KB2 |    |    |    |    |    |KW12|
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=6, y=1)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=7)
# The board state is: {'king_black_piece_2': Location(x=6, y=1), 'king_white_piece_12': Location(x=6, y=7)}
# The depth is: 1
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |KW12|
# 7 |KB2 |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=7, y=0)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=7)
# The board state is: {'king_black_piece_2': Location(x=7, y=0), 'king_white_piece_12': Location(x=6, y=7)}
# The depth is: 0
# The results of minimax are: (0, None)
# inf 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |KW12|
# 7 |    |    |KB2 |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=7, y=2)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=7)
# The board state is: {'king_black_piece_2': Location(x=7, y=2), 'king_white_piece_12': Location(x=6, y=7)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |KB2 |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |KW12|
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=5, y=0)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=7)
# The board state is: {'king_black_piece_2': Location(x=5, y=0), 'king_white_piece_12': Location(x=6, y=7)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |KB2 |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |KW12|
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=7)
# The board state is: {'king_black_piece_2': Location(x=5, y=2), 'king_white_piece_12': Location(x=6, y=7)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# The results of minimax are: (0, {'king_black_piece_2': Location(x=7, y=0), 'king_white_piece_12': Location(x=6, y=7)})
# 0 0
# The maxEval is: 0
# The results of minimax are: (0, {'king_black_piece_2': Location(x=6, y=1), 'king_white_piece_12': Location(x=6, y=5)})
# inf 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |KB2 |    |    |    |    |
# 7 |    |    |    |    |    |    |KW12|    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=6, y=3)
# The board state is: {'king_black_piece_2': Location(x=6, y=3), 'king_white_piece_12': Location(x=7, y=6)}
# The depth is: 2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |KB2 |    |KW12|    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=6, y=3)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=5)
# The board state is: {'king_black_piece_2': Location(x=6, y=3), 'king_white_piece_12': Location(x=6, y=5)}
# The depth is: 1
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |KW12|    |    |
# 7 |    |    |KB2 |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=7, y=2)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=5)
# The board state is: {'king_black_piece_2': Location(x=7, y=2), 'king_white_piece_12': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# inf 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |KW12|    |    |
# 7 |    |    |    |    |KB2 |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=7, y=4)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=5)
# The board state is: {'king_black_piece_2': Location(x=7, y=4), 'king_white_piece_12': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |KB2 |    |    |    |    |    |
# 6 |    |    |    |    |    |KW12|    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=5)
# The board state is: {'king_black_piece_2': Location(x=5, y=2), 'king_white_piece_12': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |KB2 |    |    |    |
# 6 |    |    |    |    |    |KW12|    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=5, y=4)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=5)
# The board state is: {'king_black_piece_2': Location(x=5, y=4), 'king_white_piece_12': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# The results of minimax are: (0, {'king_black_piece_2': Location(x=7, y=2), 'king_white_piece_12': Location(x=6, y=5)})
# -inf 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |KB2 |    |    |    |KW12|
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=6, y=3)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=7)
# The board state is: {'king_black_piece_2': Location(x=6, y=3), 'king_white_piece_12': Location(x=6, y=7)}
# The depth is: 1
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |KW12|
# 7 |    |    |KB2 |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=7, y=2)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=7)
# The board state is: {'king_black_piece_2': Location(x=7, y=2), 'king_white_piece_12': Location(x=6, y=7)}
# The depth is: 0
# The results of minimax are: (0, None)
# inf 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |KW12|
# 7 |    |    |    |    |KB2 |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=7, y=4)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=7)
# The board state is: {'king_black_piece_2': Location(x=7, y=4), 'king_white_piece_12': Location(x=6, y=7)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |KB2 |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |KW12|
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=7)
# The board state is: {'king_black_piece_2': Location(x=5, y=2), 'king_white_piece_12': Location(x=6, y=7)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |KB2 |    |    |    |
# 6 |    |    |    |    |    |    |    |KW12|
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=5, y=4)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=7)
# The board state is: {'king_black_piece_2': Location(x=5, y=4), 'king_white_piece_12': Location(x=6, y=7)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# The results of minimax are: (0, {'king_black_piece_2': Location(x=7, y=2), 'king_white_piece_12': Location(x=6, y=7)})
# 0 0
# The maxEval is: 0
# The results of minimax are: (0, {'king_black_piece_2': Location(x=6, y=3), 'king_white_piece_12': Location(x=6, y=5)})
# 0 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |KB2 |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |KW12|    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=4, y=1)
# The board state is: {'king_black_piece_2': Location(x=4, y=1), 'king_white_piece_12': Location(x=7, y=6)}
# The depth is: 2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |KB2 |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |KW12|    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=4, y=1)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=5)
# The board state is: {'king_black_piece_2': Location(x=4, y=1), 'king_white_piece_12': Location(x=6, y=5)}
# The depth is: 1
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |KB2 |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |KW12|    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=5, y=0)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=5)
# The board state is: {'king_black_piece_2': Location(x=5, y=0), 'king_white_piece_12': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# inf 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |KB2 |    |    |    |    |    |
# 6 |    |    |    |    |    |KW12|    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=5)
# The board state is: {'king_black_piece_2': Location(x=5, y=2), 'king_white_piece_12': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |KB2 |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |KW12|    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=3, y=0)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=5)
# The board state is: {'king_black_piece_2': Location(x=3, y=0), 'king_white_piece_12': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |KB2 |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |KW12|    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=3, y=2)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=5)
# The board state is: {'king_black_piece_2': Location(x=3, y=2), 'king_white_piece_12': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# The results of minimax are: (0, {'king_black_piece_2': Location(x=5, y=0), 'king_white_piece_12': Location(x=6, y=5)})
# -inf 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |KB2 |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |KW12|
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=4, y=1)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=7)
# The board state is: {'king_black_piece_2': Location(x=4, y=1), 'king_white_piece_12': Location(x=6, y=7)}
# The depth is: 1
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |KB2 |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |KW12|
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=5, y=0)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=7)
# The board state is: {'king_black_piece_2': Location(x=5, y=0), 'king_white_piece_12': Location(x=6, y=7)}
# The depth is: 0
# The results of minimax are: (0, None)
# inf 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |KB2 |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |KW12|
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=7)
# The board state is: {'king_black_piece_2': Location(x=5, y=2), 'king_white_piece_12': Location(x=6, y=7)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |KB2 |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |KW12|
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=3, y=0)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=7)
# The board state is: {'king_black_piece_2': Location(x=3, y=0), 'king_white_piece_12': Location(x=6, y=7)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |KB2 |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |KW12|
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=3, y=2)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=7)
# The board state is: {'king_black_piece_2': Location(x=3, y=2), 'king_white_piece_12': Location(x=6, y=7)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# The results of minimax are: (0, {'king_black_piece_2': Location(x=5, y=0), 'king_white_piece_12': Location(x=6, y=7)})
# 0 0
# The maxEval is: 0
# The results of minimax are: (0, {'king_black_piece_2': Location(x=4, y=1), 'king_white_piece_12': Location(x=6, y=5)})
# 0 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |KB2 |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |KW12|    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=4, y=3)
# The board state is: {'king_black_piece_2': Location(x=4, y=3), 'king_white_piece_12': Location(x=7, y=6)}
# The depth is: 2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |KB2 |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |KW12|    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=4, y=3)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=5)
# The board state is: {'king_black_piece_2': Location(x=4, y=3), 'king_white_piece_12': Location(x=6, y=5)}
# The depth is: 1
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |KB2 |    |    |    |    |    |
# 6 |    |    |    |    |    |KW12|    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=5)
# The board state is: {'king_black_piece_2': Location(x=5, y=2), 'king_white_piece_12': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# inf 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |KB2 |    |    |    |
# 6 |    |    |    |    |    |KW12|    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=5, y=4)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=5)
# The board state is: {'king_black_piece_2': Location(x=5, y=4), 'king_white_piece_12': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |KB2 |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |KW12|    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=3, y=2)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=5)
# The board state is: {'king_black_piece_2': Location(x=3, y=2), 'king_white_piece_12': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |KB2 |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |KW12|    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=3, y=4)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=5)
# The board state is: {'king_black_piece_2': Location(x=3, y=4), 'king_white_piece_12': Location(x=6, y=5)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# The results of minimax are: (0, {'king_black_piece_2': Location(x=5, y=2), 'king_white_piece_12': Location(x=6, y=5)})
# -inf 0
# The maxEval is: 0
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |KB2 |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |KW12|
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=4, y=3)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=7)
# The board state is: {'king_black_piece_2': Location(x=4, y=3), 'king_white_piece_12': Location(x=6, y=7)}
# The depth is: 1
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |KB2 |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |KW12|
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=7)
# The board state is: {'king_black_piece_2': Location(x=5, y=2), 'king_white_piece_12': Location(x=6, y=7)}
# The depth is: 0
# The results of minimax are: (0, None)
# inf 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |KB2 |    |    |    |
# 6 |    |    |    |    |    |    |    |KW12|
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=5, y=4)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=7)
# The board state is: {'king_black_piece_2': Location(x=5, y=4), 'king_white_piece_12': Location(x=6, y=7)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |KB2 |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |KW12|
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=3, y=2)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=7)
# The board state is: {'king_black_piece_2': Location(x=3, y=2), 'king_white_piece_12': Location(x=6, y=7)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |KB2 |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |    |    |KW12|
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_2 can move from Location(x=5, y=2) to Location(x=3, y=4)
# king_white_piece_12 can move from Location(x=7, y=6) to Location(x=6, y=7)
# The board state is: {'king_black_piece_2': Location(x=3, y=4), 'king_white_piece_12': Location(x=6, y=7)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# The results of minimax are: (0, {'king_black_piece_2': Location(x=5, y=2), 'king_white_piece_12': Location(x=6, y=7)})
# 0 0
# The maxEval is: 0
# The results of minimax are: (0, {'king_black_piece_2': Location(x=4, y=3), 'king_white_piece_12': Location(x=6, y=5)})
# 0 0
# The minEval is: 0

# %%
print('Best move:')
CheckerBoard.visualize_piece_numbers(best_move[1])
# Out:
# Best move:
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |KB2 |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |KW12|    |
#     0    1    2    3    4    5    6    7

# %% [markdown]
# #### Testing my minimax algorithm on a much more complicated board and with a depth of 2, 3, and 4
# ##### see mermaid diagram3_depth2, diagram3_depth3 to see algorithm visualized

# %%
# to view mermaid diagram, see diagram3_depth2 and diagram3_depth3
print('Initial board state:')
test_board = {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=4, y=5)}
CheckerBoard.visualize_piece_numbers(test_board)

start_time = time.time()
# white's turn
color = 'white'
intelligent_agent = IntelligentAgent(color, test_board)
# Depth of 2 is correct
best_move_depth_2 = intelligent_agent.minimax_try2(board_state=test_board, depth=2, is_maximizing=True, show_minimax_boards=True) # True for white, False for black
end_time = time.time()
time_to_find_bestmove_depth2 = end_time - start_time
# Out:
# Initial board state:
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |KW11|    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |W7  |    |
# 4 |    |    |    |    |    |KB8 |    |    |
# 5 |KW11|    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# white_piece_7 can move from Location(x=4, y=7) to Location(x=3, y=6)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 1
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |KB8 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |KW11|    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=2, y=7)
# and can capture white_piece_7
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=2, y=7)}
# The depth is: 0
# The results of minimax are: (-3, None)
# inf -3
# The minEval is: -3
# The results of minimax are: (-3, {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=2, y=7)})
# -inf -3
# The maxEval is: -3
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 1
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# inf -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |B5  |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=0)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=0), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |B5  |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=2)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=2), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |KW11|    |B6  |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |KW11|    |    |    |B6  |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=5)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=5), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |KB8 |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=5, y=6)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=5, y=6)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |KB8 |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=4)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=3, y=4)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |KB8 |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=6)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=3, y=6)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# The results of minimax are: (-2, {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)})
# -3 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |KW11|    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 1
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |KW11|    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# inf -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |B5  |    |    |    |    |    |    |    |
# 4 |    |KW11|    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=0)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=0), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |B5  |    |    |    |    |    |
# 4 |    |KW11|    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=2)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=2), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |KW11|    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |B6  |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |KW11|    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |B6  |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=5)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=5), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |KW11|    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |KB8 |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=5, y=6)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=5, y=6)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |KB8 |    |    |    |
# 4 |    |KW11|    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=4)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=3, y=4)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |KB8 |    |
# 4 |    |KW11|    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=6)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=3, y=6)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# The results of minimax are: (-2, {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=4, y=5)})
# -2 -2
# The maxEval is: -2

# %%
start_time = time.time()
# white's turn
color = 'white'
intelligent_agent = IntelligentAgent(color, test_board)
best_move_depth_3 = intelligent_agent.minimax_try2(board_state=test_board, depth=3, is_maximizing=True, show_minimax_boards=True) # True for white, False for black
end_time = time.time()
time_to_find_bestmove_depth3 = end_time - start_time
# Out:
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 3
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |W7  |    |
# 4 |    |    |    |    |    |KB8 |    |    |
# 5 |KW11|    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# white_piece_7 can move from Location(x=4, y=7) to Location(x=3, y=6)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |KB8 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |KW11|    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=2, y=7)
# and can capture white_piece_7
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=2, y=7)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |KB8 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=2, y=7)
# and can capture white_piece_7
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=2, y=7)}
# The depth is: 0
# The results of minimax are: (-3, None)
# -inf -3
# The maxEval is: -3
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |KB8 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |KW11|    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=2, y=7)
# and can capture white_piece_7
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=2, y=7)}
# The depth is: 0
# The results of minimax are: (-3, None)
# -3 -3
# The maxEval is: -3
# The results of minimax are: (-3, {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=2, y=7)})
# inf -3
# The minEval is: -3
# The results of minimax are: (-3, {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=2, y=7)})
# -inf -3
# The maxEval is: -3
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |W7  |    |
# 4 |    |    |    |    |    |KB8 |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# white_piece_7 can move from Location(x=4, y=7) to Location(x=3, y=6)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -inf -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |KW11|    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=0)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |KW11|    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=2)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=2), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |KW11|    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |KW11|    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=5, y=2)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=2), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# The results of minimax are: (-2, {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)})
# inf -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |B5  |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=0)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=0), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |B5  |    |    |    |    |    |W7  |    |
# 4 |    |    |    |    |    |KB8 |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=0)
# white_piece_7 can move from Location(x=4, y=7) to Location(x=3, y=6)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=0), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -inf -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |B5  |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |KW11|    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=0)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=0)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=0), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |B5  |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |KW11|    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=0)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=2)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=0), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=2), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |B5  |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |KW11|    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=0)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=0), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |B5  |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |KW11|    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=0)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=5, y=2)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=0), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=2), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# The results of minimax are: (-2, {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=0), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)})
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |B5  |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=2)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=2), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |B5  |    |    |    |W7  |    |
# 4 |    |    |    |    |    |KB8 |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=2)
# white_piece_7 can move from Location(x=4, y=7) to Location(x=3, y=6)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=2), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -inf -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |B5  |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |KW11|    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=2)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=0)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=2), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |B5  |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |KW11|    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=2)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=2)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=2), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=2), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |B5  |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |KW11|    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=2)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=2), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |B5  |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |KW11|    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=2)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=5, y=2)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=2), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=2), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# The results of minimax are: (-2, {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=2), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)})
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |KW11|    |B6  |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |W7  |    |
# 4 |    |    |    |    |    |KB8 |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |KW11|    |B6  |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=3)
# white_piece_7 can move from Location(x=4, y=7) to Location(x=3, y=6)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -inf -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |B6  |    |    |    |    |
# 7 |KW11|    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=0)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |B6  |    |    |    |    |
# 7 |    |    |KW11|    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=2)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=2), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |KW11|    |    |    |    |    |    |    |
# 6 |    |    |    |B6  |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=3)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |KW11|    |    |    |    |    |
# 6 |    |    |    |B6  |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=5, y=2)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=2), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# The results of minimax are: (-2, {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)})
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |KW11|    |    |    |B6  |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=5)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=5), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |W7  |    |
# 4 |    |    |    |    |    |KB8 |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |KW11|    |    |    |B6  |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=5)
# white_piece_7 can move from Location(x=4, y=7) to Location(x=3, y=6)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=5), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -inf -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |B6  |    |    |
# 7 |KW11|    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=5)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=0)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=5), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |B6  |    |    |
# 7 |    |    |KW11|    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=5)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=2)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=5), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=2), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |KW11|    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |B6  |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=5)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=5), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |KW11|    |    |    |    |    |
# 6 |    |    |    |    |    |B6  |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=5)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=5, y=2)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=5), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=2), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# The results of minimax are: (-2, {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=5), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)})
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |KB8 |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=5, y=6)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=5, y=6)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |W7  |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |KB8 |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# white_piece_7 can move from Location(x=4, y=7) to Location(x=3, y=6)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=5, y=6)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=5, y=6)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -inf -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |KB8 |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |KW11|    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=0)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=5, y=6)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=0), 'king_black_piece_8': Location(x=5, y=6)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |KB8 |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |KW11|    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=2)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=5, y=6)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=2), 'king_black_piece_8': Location(x=5, y=6)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |KW11|    |    |    |B6  |    |KB8 |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=5, y=6)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=5, y=6)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |KW11|    |B6  |    |KB8 |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=5, y=2)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=5, y=6)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=2), 'king_black_piece_8': Location(x=5, y=6)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# The results of minimax are: (-2, {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=5, y=6)})
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |KB8 |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=4)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=3, y=4)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |KB8 |    |W7  |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# white_piece_7 can move from Location(x=4, y=7) to Location(x=3, y=6)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=4)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=3, y=4)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -inf -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |KB8 |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |KW11|    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=0)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=4)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=0), 'king_black_piece_8': Location(x=3, y=4)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |KB8 |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |KW11|    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=2)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=4)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=2), 'king_black_piece_8': Location(x=3, y=4)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |KB8 |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |KW11|    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=4)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=3, y=4)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |KB8 |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |KW11|    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=5, y=2)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=4)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=2), 'king_black_piece_8': Location(x=3, y=4)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# The results of minimax are: (-2, {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=3, y=4)})
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |KB8 |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=6)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=3, y=6)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |W7  |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# white_piece_7 can move from Location(x=4, y=7) to Location(x=2, y=5)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# and can capture king_black_piece_8
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=2, y=5), 'king_white_piece_11': Location(x=6, y=1)}
# The depth is: 0
# The results of minimax are: (0, None)
# -inf 0
# The maxEval is: 0
# The results of minimax are: (0, {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=2, y=5), 'king_white_piece_11': Location(x=6, y=1)})
# -2 0
# The minEval is: -2
# The results of minimax are: (-2, {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)})
# -3 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |KW11|    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |KW11|    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |W7  |    |
# 4 |    |KW11|    |    |    |KB8 |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# white_piece_7 can move from Location(x=4, y=7) to Location(x=3, y=6)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# ...
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=5)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=5, y=2)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=5), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=2), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |KW11|    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |B6  |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=5)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=3, y=0)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=5), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=3, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |KW11|    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |B6  |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=5)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=3, y=2)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=5), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=3, y=2), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# The results of minimax are: (-2, {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=5), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=4, y=5)})
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |KW11|    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |KB8 |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=5, y=6)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=5, y=6)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |W7  |    |
# 4 |    |KW11|    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |KB8 |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# white_piece_7 can move from Location(x=4, y=7) to Location(x=3, y=6)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=5, y=6)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=5, y=6)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -inf -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |KW11|    |    |    |B6  |    |KB8 |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=5, y=6)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=5, y=6)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |KW11|    |B6  |    |KB8 |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=5, y=2)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=5, y=6)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=2), 'king_black_piece_8': Location(x=5, y=6)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |KW11|    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |KB8 |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=3, y=0)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=5, y=6)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=3, y=0), 'king_black_piece_8': Location(x=5, y=6)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |KW11|    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |KB8 |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=3, y=2)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=5, y=6)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=3, y=2), 'king_black_piece_8': Location(x=5, y=6)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# The results of minimax are: (-2, {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=5, y=6)})
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |KB8 |    |    |    |
# 4 |    |KW11|    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=4)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=3, y=4)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |KB8 |    |W7  |    |
# 4 |    |KW11|    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# white_piece_7 can move from Location(x=4, y=7) to Location(x=3, y=6)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=4)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=3, y=4)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -inf -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |KB8 |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |KW11|    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=4)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=3, y=4)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |KB8 |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |KW11|    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=5, y=2)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=4)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=2), 'king_black_piece_8': Location(x=3, y=4)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |KW11|    |    |    |KB8 |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=3, y=0)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=4)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=3, y=0), 'king_black_piece_8': Location(x=3, y=4)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |KW11|    |KB8 |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=3, y=2)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=4)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=3, y=2), 'king_black_piece_8': Location(x=3, y=4)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The maxEval is: -2
# The results of minimax are: (-2, {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=3, y=4)})
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |KB8 |    |
# 4 |    |KW11|    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=6)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=3, y=6)}
# The depth is: 1
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |W7  |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |KW11|    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# white_piece_7 can move from Location(x=4, y=7) to Location(x=2, y=5)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# and can capture king_black_piece_8
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=2, y=5), 'king_white_piece_11': Location(x=4, y=1)}
# The depth is: 0
# The results of minimax are: (0, None)
# -inf 0
# The maxEval is: 0
# The results of minimax are: (0, {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=2, y=5), 'king_white_piece_11': Location(x=4, y=1)})
# -2 0
# The minEval is: -2
# The results of minimax are: (-2, {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=4, y=5)})
# -2 -2
# The maxEval is: -2

# %%
start_time = time.time()
# white's turn
color = 'white'
intelligent_agent = IntelligentAgent(color, test_board)
best_move_depth_4 = intelligent_agent.minimax_try2(board_state=test_board, depth=4, is_maximizing=True, show_minimax_boards=True) # True for white, False for black
end_time = time.time()
time_to_find_bestmove_depth4 = end_time - start_time
# Out:
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 4
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |W7  |    |
# 4 |    |    |    |    |    |KB8 |    |    |
# 5 |KW11|    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# white_piece_7 can move from Location(x=4, y=7) to Location(x=3, y=6)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 3
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |KB8 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |KW11|    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=2, y=7)
# and can capture white_piece_7
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=2, y=7)}
# The depth is: 2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |KB8 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=2, y=7)
# and can capture white_piece_7
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=2, y=7)}
# The depth is: 1
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |KB8 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=2, y=7)
# and can capture white_piece_7
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=2, y=7)}
# The depth is: 0
# The results of minimax are: (-3, None)
# inf -3
# The minEval is: -3
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |KB8 |
# 3 |B5  |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=0)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=2, y=7)
# and can capture white_piece_7
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=0), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=2, y=7)}
# The depth is: 0
# The results of minimax are: (-3, None)
# -3 -3
# The minEval is: -3
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |KB8 |
# 3 |    |    |B5  |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=2)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=2, y=7)
# and can capture white_piece_7
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=2), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=2, y=7)}
# The depth is: 0
# The results of minimax are: (-3, None)
# -3 -3
# The minEval is: -3
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |KB8 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |KW11|    |B6  |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=2, y=7)
# and can capture white_piece_7
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=3), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=2, y=7)}
# The depth is: 0
# The results of minimax are: (-3, None)
# -3 -3
# The minEval is: -3
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |KB8 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |KW11|    |    |    |B6  |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=5)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=2, y=7)
# and can capture white_piece_7
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=5), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=2, y=7)}
# The depth is: 0
# The results of minimax are: (-3, None)
# -3 -3
# The minEval is: -3
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |KB8 |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=6)
# and can capture white_piece_7
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=3, y=6)}
# The depth is: 0
# The results of minimax are: (-3, None)
# -3 -3
# The minEval is: -3
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |KB8 |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=1, y=6)
# and can capture white_piece_7
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=1, y=6)}
# The depth is: 0
# The results of minimax are: (-3, None)
# -3 -3
# The minEval is: -3
# The results of minimax are: (-3, {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=2, y=7)})
# -inf -3
# The maxEval is: -3
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |KB8 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |KW11|    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=2, y=7)
# and can capture white_piece_7
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=2, y=7)}
# The depth is: 1
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |KB8 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |KW11|    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=2, y=7)
# and can capture white_piece_7
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=2, y=7)}
# The depth is: 0
# The results of minimax are: (-3, None)
# inf -3
# The minEval is: -3
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |KB8 |
# 3 |B5  |    |    |    |    |    |    |    |
# 4 |    |KW11|    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=0)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=2, y=7)
# and can capture white_piece_7
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=0), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=2, y=7)}
# The depth is: 0
# The results of minimax are: (-3, None)
# -3 -3
# The minEval is: -3
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |KB8 |
# 3 |    |    |B5  |    |    |    |    |    |
# 4 |    |KW11|    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=2)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=2, y=7)
# and can capture white_piece_7
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=2), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=2, y=7)}
# The depth is: 0
# The results of minimax are: (-3, None)
# -3 -3
# The minEval is: -3
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |KB8 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |KW11|    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |B6  |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=2, y=7)
# and can capture white_piece_7
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=3), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=2, y=7)}
# The depth is: 0
# The results of minimax are: (-3, None)
# -3 -3
# The minEval is: -3
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |KB8 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |KW11|    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |B6  |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=5)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=2, y=7)
# and can capture white_piece_7
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=5), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=2, y=7)}
# The depth is: 0
# The results of minimax are: (-3, None)
# -3 -3
# The minEval is: -3
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |KB8 |    |
# 4 |    |KW11|    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=6)
# and can capture white_piece_7
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=3, y=6)}
# The depth is: 0
# The results of minimax are: (-3, None)
# -3 -3
# The minEval is: -3
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |KB8 |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |KW11|    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=1, y=6)
# and can capture white_piece_7
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=1, y=6)}
# The depth is: 0
# The results of minimax are: (-3, None)
# -3 -3
# The minEval is: -3
# The results of minimax are: (-3, {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=2, y=7)})
# -3 -3
# The maxEval is: -3
# The results of minimax are: (-3, {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=2, y=7)})
# inf -3
# The minEval is: -3
# The results of minimax are: (-3, {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=2, y=7)})
# -inf -3
# The maxEval is: -3
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 3
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |W7  |    |
# 4 |    |    |    |    |    |KB8 |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# white_piece_7 can move from Location(x=4, y=7) to Location(x=3, y=6)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 1
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |KB8 |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=6, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=2, y=7)
# and can capture white_piece_7
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=2, y=7)}
# The depth is: 0
# The results of minimax are: (-3, None)
# inf -3
# The minEval is: -3
# The results of minimax are: (-3, {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'king_white_piece_11': Location(x=6, y=1), 'king_black_piece_8': Location(x=2, y=7)})
# -inf -3
# The maxEval is: -3
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |KW11|    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=0)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 1
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |B1  |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |KW11|    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=3, y=2)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=0)
# The board state is: {'black_piece_1': Location(x=3, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# inf -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |B1  |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |KW11|    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=3, y=4)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=0)
# The board state is: {'black_piece_1': Location(x=3, y=4), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |B1  |    |    |    |    |
# 3 |B5  |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |KW11|    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=0)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=0)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=3, y=0), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |B1  |    |    |    |    |
# 3 |    |    |B5  |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |KW11|    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=2)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=0)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=3, y=2), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |B6  |    |    |    |    |
# 7 |KW11|    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=0)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |B6  |    |    |
# 7 |KW11|    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=5)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=0)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=5), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |KB8 |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |KW11|    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=0)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=5, y=6)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=0), 'king_black_piece_8': Location(x=5, y=6)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |KB8 |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |KW11|    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=0)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=4)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=0), 'king_black_piece_8': Location(x=3, y=4)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |KB8 |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |KW11|    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=0)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=6)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=0), 'king_black_piece_8': Location(x=3, y=6)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# The results of minimax are: (-2, {'black_piece_1': Location(x=3, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=0), 'king_black_piece_8': Location(x=4, y=5)})
# -3 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |KW11|    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=2)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=2), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 1
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |B1  |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |KW11|    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=3, y=2)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=2)
# The board state is: {'black_piece_1': Location(x=3, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=2), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# inf -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |B1  |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |KW11|    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=3, y=4)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=2)
# The board state is: {'black_piece_1': Location(x=3, y=4), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=2), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |B1  |    |    |    |    |
# 3 |B5  |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |KW11|    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=0)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=2)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=3, y=0), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=2), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |B1  |    |    |    |    |
# 3 |    |    |B5  |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |KW11|    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=2)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=2)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=3, y=2), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=2), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |B6  |    |    |    |    |
# 7 |    |    |KW11|    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=2)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=2), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |B6  |    |    |
# 7 |    |    |KW11|    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=5)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=2)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=5), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=2), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |KB8 |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |KW11|    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=2)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=5, y=6)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=2), 'king_black_piece_8': Location(x=5, y=6)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |KB8 |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |KW11|    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=2)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=4)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=2), 'king_black_piece_8': Location(x=3, y=4)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |KB8 |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |KW11|    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=7, y=2)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=6)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=2), 'king_black_piece_8': Location(x=3, y=6)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# The results of minimax are: (-2, {'black_piece_1': Location(x=3, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=7, y=2), 'king_black_piece_8': Location(x=4, y=5)})
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |KW11|    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 1
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |B1  |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |KW11|    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=3, y=2)
# The board state is: {'black_piece_1': Location(x=3, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# inf -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |B1  |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |KW11|    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=3, y=4)
# The board state is: {'black_piece_1': Location(x=3, y=4), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |B1  |    |    |    |    |
# 3 |B5  |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |KW11|    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=0)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=3, y=0), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |    |    |B1  |    |    |    |    |
# 3 |    |    |B5  |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |KW11|    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=2)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=3, y=2), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |KW11|    |    |    |    |    |    |    |
# 6 |    |    |    |B6  |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=3)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |KW11|    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |B6  |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=5)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=5), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |KW11|    |    |    |B6  |    |KB8 |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=5, y=6)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=5, y=6)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |    |    |    |
# 3 |    |    |    |    |KB8 |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |KW11|    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=4)
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=5, y=0), 'king_black_piece_8': Location(x=3, y=4)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# ...
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |KW11|    |B5  |    |KB8 |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=2)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=3, y=0)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=4)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=2), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=3, y=0), 'king_black_piece_8': Location(x=3, y=4)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |KW11|    |    |    |KB8 |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |B6  |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=3)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=3, y=0)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=4)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=3, y=0), 'king_black_piece_8': Location(x=3, y=4)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |KW11|    |    |    |KB8 |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |B6  |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=5)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=3, y=0)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=4)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=5), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=3, y=0), 'king_black_piece_8': Location(x=3, y=4)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |KW11|    |    |    |    |    |    |    |
# 4 |    |    |    |KB8 |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=3, y=0)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=4, y=3)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=3, y=0), 'king_black_piece_8': Location(x=4, y=3)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |KW11|    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=3, y=0)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=3, y=0), 'king_black_piece_8': Location(x=4, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |KB8 |    |    |    |    |
# 3 |KW11|    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=3, y=0)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=2, y=3)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=3, y=0), 'king_black_piece_8': Location(x=2, y=3)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |KB8 |    |    |
# 3 |KW11|    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=3, y=0)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=2, y=5)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=3, y=0), 'king_black_piece_8': Location(x=2, y=5)}
# The depth is: 0
# The results of minimax are: (-2, None)
# -2 -2
# The minEval is: -2
# The results of minimax are: (-2, {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=3, y=0), 'king_black_piece_8': Location(x=3, y=4)})
# -2 -2
# The maxEval is: -2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |KW11|    |KB8 |    |    |    |
# 4 |    |    |    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=3, y=2)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=4)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=3, y=2), 'king_black_piece_8': Location(x=3, y=4)}
# The depth is: 1
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |    |    |    |
# 3 |    |    |    |    |KB8 |    |    |    |
# 4 |    |    |    |B5  |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=4, y=3)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=4)
# and can capture king_white_piece_11
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=4, y=3), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_black_piece_8': Location(x=3, y=4)}
# The depth is: 0
# The results of minimax are: (-4, None)
# inf -4
# The minEval is: -4
# The results of minimax are: (-4, {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=4, y=3), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_black_piece_8': Location(x=3, y=4)})
# -2 -4
# The maxEval is: -2
# The results of minimax are: (-2, {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=3, y=6), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=3, y=4)})
# -2 -2
# The minEval is: -2
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |KB8 |    |
# 4 |    |KW11|    |    |    |    |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# king_black_piece_8 can move from Location(x=4, y=5) to Location(x=3, y=6)
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=3, y=6)}
# The depth is: 2
# White's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |W7  |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |KW11|    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# white_piece_7 can move from Location(x=4, y=7) to Location(x=2, y=5)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# and can capture king_black_piece_8
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=2, y=5), 'king_white_piece_11': Location(x=4, y=1)}
# The depth is: 1
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |    |    |    |    |    |    |
# 2 |    |B5  |    |B1  |    |W7  |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |KW11|    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_1 can move from Location(x=1, y=2) to Location(x=2, y=3)
# white_piece_7 can move from Location(x=4, y=7) to Location(x=2, y=5)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# and can capture king_black_piece_8
# The board state is: {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=2, y=5), 'king_white_piece_11': Location(x=4, y=1)}
# The depth is: 0
# The results of minimax are: (0, None)
# inf 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |W7  |    |    |
# 3 |B5  |    |    |    |    |    |    |    |
# 4 |    |KW11|    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=0)
# white_piece_7 can move from Location(x=4, y=7) to Location(x=2, y=5)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# and can capture king_black_piece_8
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=0), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=2, y=5), 'king_white_piece_11': Location(x=4, y=1)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |    |    |    |    |W7  |    |    |
# 3 |    |    |B5  |    |    |    |    |    |
# 4 |    |KW11|    |    |    |    |    |    |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |    |    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_5 can move from Location(x=2, y=1) to Location(x=3, y=2)
# white_piece_7 can move from Location(x=4, y=7) to Location(x=2, y=5)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# and can capture king_black_piece_8
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=3, y=2), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=2, y=5), 'king_white_piece_11': Location(x=4, y=1)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |W7  |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |KW11|    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |B6  |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=3)
# white_piece_7 can move from Location(x=4, y=7) to Location(x=2, y=5)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# and can capture king_black_piece_8
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=3), 'white_piece_7': Location(x=2, y=5), 'king_white_piece_11': Location(x=4, y=1)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# Black's turn
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |W7  |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |KW11|    |    |    |    |    |    |
# 5 |    |    |    |    |    |    |    |    |
# 6 |    |    |    |    |    |B6  |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# black_piece_6 can move from Location(x=5, y=4) to Location(x=6, y=5)
# white_piece_7 can move from Location(x=4, y=7) to Location(x=2, y=5)
# king_white_piece_11 can move from Location(x=5, y=0) to Location(x=4, y=1)
# and can capture king_black_piece_8
# The board state is: {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=6, y=5), 'white_piece_7': Location(x=2, y=5), 'king_white_piece_11': Location(x=4, y=1)}
# The depth is: 0
# The results of minimax are: (0, None)
# 0 0
# The minEval is: 0
# The results of minimax are: (0, {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=2, y=5), 'king_white_piece_11': Location(x=4, y=1)})
# -inf 0
# The maxEval is: 0
# The results of minimax are: (0, {'black_piece_1': Location(x=1, y=2), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=2, y=5), 'king_white_piece_11': Location(x=4, y=1)})
# -2 0
# The minEval is: -2
# The results of minimax are: (-2, {'black_piece_1': Location(x=2, y=3), 'black_piece_5': Location(x=2, y=1), 'black_piece_6': Location(x=5, y=4), 'white_piece_7': Location(x=4, y=7), 'king_white_piece_11': Location(x=4, y=1), 'king_black_piece_8': Location(x=4, y=5)})
# -2 -2
# The maxEval is: -2

# %%
print('Best move with a depth of 2:')
print("Time to find best move with depth 2: ", time_to_find_bestmove_depth2)
CheckerBoard.visualize_piece_numbers(best_move_depth_2[1])

print('Best move with a depth of 3:')
print("Time to find best move with depth 3: ", time_to_find_bestmove_depth3)
CheckerBoard.visualize_piece_numbers(best_move_depth_3[1])

print('Best move with a depth of 4:')
print("Time to find best move with depth 4: ", time_to_find_bestmove_depth4)
CheckerBoard.visualize_piece_numbers(best_move_depth_4[1])
# Out:
# Best move with a depth of 2:
# Time to find best move with depth 2:  0.06096959114074707
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# Best move with a depth of 3:
# Time to find best move with depth 3:  0.3520543575286865
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7
# Best move with a depth of 4:
# Time to find best move with depth 4:  2.446997880935669
# 0 |    |    |    |    |    |    |    |    |
# 1 |    |    |B1  |    |    |    |    |    |
# 2 |    |B5  |    |    |    |    |    |    |
# 3 |    |    |    |    |    |    |    |    |
# 4 |    |    |    |    |    |KB8 |    |W7  |
# 5 |    |    |    |    |B6  |    |    |    |
# 6 |    |KW11|    |    |    |    |    |    |
# 7 |    |    |    |    |    |    |    |    |
#     0    1    2    3    4    5    6    7

# %% [markdown]
# #### Note: The best move for this specific board state is the same with a minimax algorithm depth of 2, 3, or 4 --> KW11 moves from (5,0) to (6,1)
# #### It also took 40x longer to build a tree with depth 4 vs a tree with depth 2
